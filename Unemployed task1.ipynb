# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
''' LEVEL 1 TASK

UNEMPLOYMENT IN INDIA

• Unemployment is measured by the unemployment rate which is the number of
people who are unemployed as a percentage of the total labour force.

• We have seen a sharp increase in the unemployment rate during Covid-19,

• so analyzing the unemployment rate can be a good data science project.'''
# Out:
# ' LEVEL 1 TASK\n\nUNEMPLOYMENT IN INDIA\n\n• Unemployment is measured by the unemployment rate which is the number of\npeople who are unemployed as a percentage of the total labour force.\n\n• We have seen a sharp increase in the unemployment rate during Covid-19,\n\n• so analyzing the unemployment rate can be a good data science project.'

# %% [markdown]
# ### Data extraction

# %%
unemployment_india = pd.read_csv("Unemployment in India.csv")

# %%
unemployment_rate = pd.read_csv("Unemployment_Rate_upto_11_2020.csv")

# %% [markdown]
# ### checking the data

# %%
unemployment_india.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
unemployment_india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
unemployment_rate.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# 1    15.9129     79.74
# 2    15.9129     79.74
# 3    15.9129     79.74
# 4    15.9129     79.74

# %%
unemployment_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %% [markdown]
# ### here we are converting column names to lowercase

# %%
unemployment_india.columns = unemployment_india.columns.str.strip().str.lower()
unemployment_india.columns
# Out:
# Index(['region', 'date', 'frequency', 'estimated unemployment rate (%)',
#        'estimated employed', 'estimated labour participation rate (%)',
#        'area'],
#       dtype='object')

# %%
unemployment_rate.columns = unemployment_rate.columns.str.strip().str.lower()
unemployment_rate.columns
# Out:
# Index(['region', 'date', 'frequency', 'estimated unemployment rate (%)',
#        'estimated employed', 'estimated labour participation rate (%)',
#        'region.1', 'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# ### type casting

# %%
unemployment_india['date'] = pd.to_datetime(unemployment_india['date'],dayfirst=True)

# %%
unemployment_rate['date']=unemployment_rate['date'].apply(pd.to_datetime)

# %%
#Unemployment is measured by the unemployment rate which is the number of
#people who are unemployed as a percentage of the total labour force.

# %% [markdown]
# ### data merging by concat

# %%
df=pd.concat([unemployment_india,unemployment_rate], ignore_index=True)
df
# Out:
#               region       date frequency  estimated unemployment rate (%)  \
# 0     Andhra Pradesh 2019-05-31   Monthly                             3.65
# 1     Andhra Pradesh 2019-06-30   Monthly                             3.05
# 2     Andhra Pradesh 2019-07-31   Monthly                             3.75
# 3     Andhra Pradesh 2019-08-31   Monthly                             3.32
# 4     Andhra Pradesh 2019-09-30   Monthly                             5.17
# ...              ...        ...       ...                              ...
# 1030     West Bengal 2020-06-30         M                             7.29
# 1031     West Bengal 2020-07-31         M                             6.83
# 1032     West Bengal 2020-08-31         M                            14.87
# 1033     West Bengal 2020-09-30         M                             9.35
# 1034     West Bengal 2020-10-31         M                             9.98
#
#       estimated employed  estimated labour participation rate (%)   area  \
# 0             11999139.0                                    43.24  Rural
# 1             11755881.0                                    42.05  Rural
# 2             12086707.0                                    43.50  Rural
# 3             12285693.0                                    43.97  Rural
# 4             12256762.0                                    44.68  Rural
# ...                  ...                                      ...    ...
# 1030          30726310.0                                    40.39    NaN
# 1031          35372506.0                                    46.17    NaN
# 1032          33298644.0                                    47.48    NaN
# 1033          35707239.0                                    47.73    NaN
# 1034          33962549.0                                    45.63    NaN
#
#      region.1  longitude  latitude
# 0         NaN        NaN       NaN
# 1         NaN        NaN       NaN
# 2         NaN        NaN       NaN
# 3         NaN        NaN       NaN
# 4         NaN        NaN       NaN
# ...       ...        ...       ...
# 1030     East    22.9868    87.855
# 1031     East    22.9868    87.855
# 1032     East    22.9868    87.855
# 1033     East    22.9868    87.855
# 1034     East    22.9868    87.855
#
# [1035 rows x 10 columns]

# %%
df['frequency']=df['frequency'].str.replace("M", "Monthly")
df.tail()
# Out:
#            region       date frequency  estimated unemployment rate (%)  \
# 1030  West Bengal 2020-06-30   Monthly                             7.29
# 1031  West Bengal 2020-07-31   Monthly                             6.83
# 1032  West Bengal 2020-08-31   Monthly                            14.87
# 1033  West Bengal 2020-09-30   Monthly                             9.35
# 1034  West Bengal 2020-10-31   Monthly                             9.98
#
#       estimated employed  estimated labour participation rate (%) area  \
# 1030          30726310.0                                    40.39  NaN
# 1031          35372506.0                                    46.17  NaN
# 1032          33298644.0                                    47.48  NaN
# 1033          35707239.0                                    47.73  NaN
# 1034          33962549.0                                    45.63  NaN
#
#      region.1  longitude  latitude
# 1030     East    22.9868    87.855
# 1031     East    22.9868    87.855
# 1032     East    22.9868    87.855
# 1033     East    22.9868    87.855
# 1034     East    22.9868    87.855

# %%
df.isna().sum()
# Out:
# region                                      28
# date                                        28
# frequency                                   28
# estimated unemployment rate (%)             28
# estimated employed                          28
# estimated labour participation rate (%)     28
# area                                       295
# region.1                                   768
# longitude                                  768
# latitude                                   768
# dtype: int64

# %%
df['region'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', nan, 'Chandigarh'],
#       dtype=object)

# %%
df['unemployment']= (df['estimated unemployment rate (%)']/df['estimated labour participation rate (%)'])*100
df['unemployment']
# Out:
# 0        8.441258
# 1        7.253270
# 2        8.620690
# 3        7.550603
# 4       11.571173
#           ...
# 1030    18.049022
# 1031    14.793156
# 1032    31.318450
# 1033    19.589357
# 1034    21.871576
# Name: unemployment, Length: 1035, dtype: float64

# %%
df.duplicated().sum()
# Out:
# 27

# %%
df.shape
# Out:
# (1035, 11)

# %%
df.drop_duplicates(inplace=True)

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.shape
# Out:
# (1008, 11)

# %%
df.head(20)
# Out:
#             region       date       frequency  \
# 0   Andhra Pradesh 2019-05-31   Monthlyonthly
# 1   Andhra Pradesh 2019-06-30   Monthlyonthly
# 2   Andhra Pradesh 2019-07-31   Monthlyonthly
# 3   Andhra Pradesh 2019-08-31   Monthlyonthly
# 4   Andhra Pradesh 2019-09-30   Monthlyonthly
# 5   Andhra Pradesh 2019-10-31   Monthlyonthly
# 6   Andhra Pradesh 2019-11-30   Monthlyonthly
# 7   Andhra Pradesh 2019-12-31   Monthlyonthly
# 8   Andhra Pradesh 2020-01-31   Monthlyonthly
# 9   Andhra Pradesh 2020-02-29   Monthlyonthly
# 10  Andhra Pradesh 2020-03-31   Monthlyonthly
# 11  Andhra Pradesh 2020-04-30   Monthlyonthly
# 12  Andhra Pradesh 2020-05-31   Monthlyonthly
# 13  Andhra Pradesh 2020-06-30   Monthlyonthly
# 14           Assam 2019-05-31   Monthlyonthly
# 15           Assam 2019-06-30   Monthlyonthly
# 16           Assam 2019-07-31   Monthlyonthly
# 17           Assam 2019-08-31   Monthlyonthly
# 18           Assam 2019-09-30   Monthlyonthly
# 19           Assam 2019-10-31   Monthlyonthly
#
#     estimated unemployment rate (%)  estimated employed  \
# 0                              3.65          11999139.0
# 1                              3.05          11755881.0
# 2                              3.75          12086707.0
# 3                              3.32          12285693.0
# 4                              5.17          12256762.0
# 5                              3.52          12017412.0
# 6                              4.12          11397681.0
# 7                              4.38          12528395.0
# 8                              4.84          12016676.0
# 9                              5.91          11723617.0
# 10                             4.06          11359660.0
# 11                            16.29           8792827.0
# 12                            14.46           9526902.0
# 13                             0.85          15572975.0
# 14                             4.29          11749334.0
# 15                             5.08           8923222.0
# 16                             4.26           9911534.0
# 17                             5.79           9292039.0
# 18                             4.46          11468349.0
# 19                             4.65           8395906.0
#
#     estimated labour participation rate (%)   area region.1  longitude  \
# 0                                     43.24  Rural      NaN        NaN
# 1                                     42.05  Rural      NaN        NaN
# 2                                     43.50  Rural      NaN        NaN
# 3                                     43.97  Rural      NaN        NaN
# 4                                     44.68  Rural      NaN        NaN
# 5                                     43.01  Rural      NaN        NaN
# 6                                     41.00  Rural      NaN        NaN
# 7                                     45.14  Rural      NaN        NaN
# 8                                     43.46  Rural      NaN        NaN
# 9                                     42.83  Rural      NaN        NaN
# 10                                    40.66  Rural      NaN        NaN
# 11                                    36.03  Rural      NaN        NaN
# 12                                    38.16  Rural      NaN        NaN
# 13                                    53.76  Rural      NaN        NaN
# 14                                    57.39  Rural      NaN        NaN
# 15                                    43.87  Rural      NaN        NaN
# 16                                    48.21  Rural      NaN        NaN
# 17                                    45.83  Rural      NaN        NaN
# 18                                    55.67  Rural      NaN        NaN
# 19                                    40.76  Rural      NaN        NaN
#
#     latitude  unemployment
# 0        NaN      8.441258
# 1        NaN      7.253270
# 2        NaN      8.620690
# 3        NaN      7.550603
# 4        NaN     11.571173
# 5        NaN      8.184143
# 6        NaN     10.048780
# 7        NaN      9.703146
# 8        NaN     11.136677
# 9        NaN     13.798739
# 10       NaN      9.985243
# 11       NaN     45.212323
# 12       NaN     37.893082
# 13       NaN      1.581101
# 14       NaN      7.475170
# 15       NaN     11.579667
# 16       NaN      8.836341
# 17       NaN     12.633646
# 18       NaN      8.011496
# 19       NaN     11.408243

# %%
#region_stats = df.groupby(['region'])[['estimated unemployment rate','estimated employed','estimated labour participation rate']].mean().reset_index()
#region_stats

# %%
unemp_mean = df.groupby('region')['estimated unemployment rate (%)'].mean().sort_values(ascending=False)
unemp_mean
# Out:
# region
# Tripura             27.483158
# Haryana             26.597368
# Jharkhand           20.309737
# Bihar               19.063684
# Himachal Pradesh    17.888947
# Delhi               17.000263
# Jammu & Kashmir     16.275333
# Chandigarh          15.991667
# Rajasthan           14.534474
# Puducherry          12.361389
# Punjab              12.017895
# Uttar Pradesh       11.810789
# Goa                 10.125000
# Tamil Nadu          10.048158
# Kerala               9.942368
# Chhattisgarh         8.866316
# West Bengal          8.668684
# Sikkim               8.063200
# Uttarakhand          7.818919
# Andhra Pradesh       7.789474
# Maharashtra          7.668421
# Telangana            7.499737
# Madhya Pradesh       7.261053
# Karnataka            6.937105
# Gujarat              6.588158
# Assam                5.991389
# Odisha               5.869474
# Meghalaya            4.546757
# Name: estimated unemployment rate (%), dtype: float64

# %%
unemp_mean.plot(kind='barh')
# Out:
# <Axes: ylabel='region'>

# %%
unempl_mean = df.groupby('region')['unemployment'].mean().sort_values(ascending=False)
unempl_mean
# Out:
# region
# Haryana             62.920251
# Bihar               50.519183
# Jharkhand           50.111938
# Delhi               47.442728
# Tripura             45.374517
# Jammu & Kashmir     40.559708
# Chandigarh          40.291544
# Himachal Pradesh    39.836917
# Rajasthan           36.848527
# Puducherry          33.633724
# Tamil Nadu          32.200083
# Kerala              32.027223
# Uttar Pradesh       30.124629
# Punjab              29.395505
# Goa                 25.265980
# Uttarakhand         23.222464
# Chhattisgarh        22.289849
# Andhra Pradesh      21.683918
# West Bengal         19.646170
# Maharashtra         19.633460
# Madhya Pradesh      19.172526
# Odisha              17.522107
# Sikkim              16.983050
# Karnataka           16.230732
# Gujarat             15.581904
# Telangana           15.028215
# Assam               13.805033
# Meghalaya            8.932964
# Name: unemployment, dtype: float64

# %%
unempl_mean.plot(kind='barh')
# Out:
# <Axes: ylabel='region'>

# %%
labour_mean = df.groupby('region')['estimated labour participation rate (%)'].mean().sort_values(ascending=False)
labour_mean
# Out:
# region
# Tripura             60.777632
# Meghalaya           57.831622
# Telangana           53.520789
# Sikkim              45.969600
# Gujarat             45.940263
# West Bengal         45.349211
# Assam               44.487778
# Himachal Pradesh    43.177368
# Haryana             42.569474
# Chhattisgarh        42.376579
# Maharashtra         42.082895
# Karnataka           41.517632
# Jharkhand           41.324737
# Punjab              40.833158
# Rajasthan           40.135789
# Jammu & Kashmir     40.090000
# Tamil Nadu          39.953947
# Chandigarh          39.336667
# Andhra Pradesh      39.266842
# Goa                 39.247353
# Uttar Pradesh       38.952368
# Madhya Pradesh      38.848947
# Odisha              38.616316
# Puducherry          38.138611
# Delhi               38.121053
# Bihar               37.895789
# Kerala              34.476842
# Uttarakhand         34.176486
# Name: estimated labour participation rate (%), dtype: float64

# %%
labour_mean.plot(kind='barh')
# Out:
# <Axes: ylabel='region'>

# %%
df.head()
# Out:
#            region       date       frequency  estimated unemployment rate (%)  \
# 0  Andhra Pradesh 2019-05-31   Monthlyonthly                             3.65
# 1  Andhra Pradesh 2019-06-30   Monthlyonthly                             3.05
# 2  Andhra Pradesh 2019-07-31   Monthlyonthly                             3.75
# 3  Andhra Pradesh 2019-08-31   Monthlyonthly                             3.32
# 4  Andhra Pradesh 2019-09-30   Monthlyonthly                             5.17
#
#    estimated employed  estimated labour participation rate (%)   area  \
# 0          11999139.0                                    43.24  Rural
# 1          11755881.0                                    42.05  Rural
# 2          12086707.0                                    43.50  Rural
# 3          12285693.0                                    43.97  Rural
# 4          12256762.0                                    44.68  Rural
#
#   region.1  longitude  latitude  unemployment
# 0      NaN        NaN       NaN      8.441258
# 1      NaN        NaN       NaN      7.253270
# 2      NaN        NaN       NaN      8.620690
# 3      NaN        NaN       NaN      7.550603
# 4      NaN        NaN       NaN     11.571173

# %%
sns.boxplot(data=df,x='region',y='unemployment')
plt.title('Detecting Outliers in unemployment rates')
plt.ylabel("unemployment rate")
plt.xlabel("region")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.boxplot(data=df,x='region',y='estimated labour participation rate (%)')
plt.title('Detecting Outliers in estimated labour participation rate')
plt.ylabel("unemployment rate")
plt.xlabel("region")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.boxplot(data=df,x='region',y='estimated unemployment rate (%)')
plt.title('Detecting Outliers in estimated unemployment rate')
plt.ylabel("unemployment rate")
plt.xlabel("region")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.boxplot(data=df,x='region',y='estimated employed')
plt.title('Detecting Outliers in estimated employed')
plt.ylabel("unemployment rate")
plt.xlabel("region")
plt.xticks(rotation = 90)
plt.show()

# %%
df.head()
# Out:
#            region       date       frequency  estimated unemployment rate (%)  \
# 0  Andhra Pradesh 2019-05-31   Monthlyonthly                             3.65
# 1  Andhra Pradesh 2019-06-30   Monthlyonthly                             3.05
# 2  Andhra Pradesh 2019-07-31   Monthlyonthly                             3.75
# 3  Andhra Pradesh 2019-08-31   Monthlyonthly                             3.32
# 4  Andhra Pradesh 2019-09-30   Monthlyonthly                             5.17
#
#    estimated employed  estimated labour participation rate (%)   area  \
# 0          11999139.0                                    43.24  Rural
# 1          11755881.0                                    42.05  Rural
# 2          12086707.0                                    43.50  Rural
# 3          12285693.0                                    43.97  Rural
# 4          12256762.0                                    44.68  Rural
#
#   region.1  longitude  latitude  unemployment
# 0      NaN        NaN       NaN      8.441258
# 1      NaN        NaN       NaN      7.253270
# 2      NaN        NaN       NaN      8.620690
# 3      NaN        NaN       NaN      7.550603
# 4      NaN        NaN       NaN     11.571173

# %%
df['year'] = df['date'].dt.year

# %%
df['year'] = pd.to_datetime(df['year'],dayfirst=True)
df['year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 1008 entries, 0 to 1034
# Series name: year
# Non-Null Count  Dtype
# --------------  -----
# 1007 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 15.8 KB

# %%
sns.barplot(data=df, x='region', y='estimated unemployment rate (%)', hue='year')
plt.title('Percentage of estimated unemployment rate rate per month')
plt.ylabel('Estimated Unemployment rate')
plt.xticks(rotation= 90)
plt.show()

# %%
sns.barplot(data=df, x='region', y='unemployment', hue='year')
plt.title('Percentage of estimated unemployment rate rate per month')
plt.ylabel('Estimated Unemployment rate')
plt.xticks(rotation= 90)
plt.show()

# %%
sns.barplot(data=df, x='region', y='estimated employed', hue='year')
plt.title('Percentage of estimated unemployment rate rate per month')
plt.ylabel('Estimated Unemployment rate')
plt.xticks(rotation= 90)
plt.show()

# %%
pip install Basemap
# Out:
# Requirement already satisfied: Basemap in c:\users\srujan\anaconda2\lib\site-packages (1.3.9)
# Requirement already satisfied: pyproj<3.7.0,>=1.9.3 in c:\users\srujan\anaconda2\lib\site-packages (from Basemap) (3.6.1)
# Requirement already satisfied: matplotlib<3.8,>=1.5 in c:\users\srujan\anaconda2\lib\site-packages (from Basemap) (3.7.0)
# Requirement already satisfied: numpy<1.26,>=1.21 in c:\users\srujan\anaconda2\lib\site-packages (from Basemap) (1.23.5)
# Requirement already satisfied: basemap-data<1.4,>=1.3.2 in c:\users\srujan\anaconda2\lib\site-packages (from Basemap) (1.3.2)
# Requirement already satisfied: pyshp<2.4,>=1.2 in c:\users\srujan\anaconda2\lib\site-packages (from Basemap) (2.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\srujan\anaconda2\lib\site-packages (from matplotlib<3.8,>=1.5->Basemap) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\srujan\anaconda2\lib\site-packages (from matplotlib<3.8,>=1.5->Basemap) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\srujan\anaconda2\lib\site-packages (from matplotlib<3.8,>=1.5->Basemap) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\srujan\anaconda2\lib\site-packages (from matplotlib<3.8,>=1.5->Basemap) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\srujan\anaconda2\lib\site-packages (from matplotlib<3.8,>=1.5->Basemap) (22.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\srujan\anaconda2\lib\site-packages (from matplotlib<3.8,>=1.5->Basemap) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\srujan\anaconda2\lib\site-packages (from matplotlib<3.8,>=1.5->Basemap) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\srujan\anaconda2\lib\site-packages (from matplotlib<3.8,>=1.5->Basemap) (2.8.2)
# Requirement already satisfied: certifi in c:\users\srujan\anaconda2\lib\site-packages (from pyproj<3.7.0,>=1.9.3->Basemap) (2023.5.7)
# Requirement already satisfied: six>=1.5 in c:\users\srujan\anaconda2\lib\site-packages (from python-dateutil>=2.7->matplotlib<3.8,>=1.5->Basemap) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from mpl_toolkits.basemap import Basemap

map = Basemap(projection='mill', llcrnrlat=-80, urcrnrlat=80, llcrnrlon=-180, urcrnrlon=180)

# Draw coastlines, countries, and states
map.drawcoastlines()
map.drawcountries()
map.drawstates()

# Convert latitude and longitude to map coordinates
x, y = map(df['latitude'],df['longitude'])

# Plot points on the map
map.scatter(x, y, marker='o', color='red')

# Show the map
plt.title('Map with Latitude and Longitude Data')
plt.show()
