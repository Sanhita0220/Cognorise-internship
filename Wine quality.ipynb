# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
def numerical_data(data):
    for col in data:
        print('*'*20, col, '*'*20, '\n')
        print(data[col].agg(['count', 'min','max', 'mean', 'median', 'std', 'skew', 'kurt']))
        print()

# %%
numerical_columns = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']

# %%
numerical_data(df[numerical_columns])
# Out:
# ******************** fixed acidity ********************
#
# count     1599.000000
# min          4.600000
# max         15.900000
# mean         8.319637
# median       7.900000
# std          1.741096
# skew         0.982751
# kurt         1.132143
# Name: fixed acidity, dtype: float64
#
# ******************** volatile acidity ********************
#
# count     1599.000000
# min          0.120000
# max          1.580000
# mean         0.527821
# median       0.520000
# std          0.179060
# skew         0.671593
# kurt         1.225542
# Name: volatile acidity, dtype: float64
#
# ******************** citric acid ********************
#
# count     1599.000000
# min          0.000000
# max          1.000000
# mean         0.270976
# median       0.260000
# std          0.194801
# skew         0.318337
# kurt        -0.788998
# Name: citric acid, dtype: float64
#
# ******************** residual sugar ********************
#
# count     1599.000000
# min          0.900000
# ...

# %%
numerical_columns = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides',
                     'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol']

# Boxplots for numerical columns
for column in numerical_columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot of {column}')
    plt.show()

# Histograms/Density plots for numerical columns
for column in numerical_columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()

# Scatterplots against 'quality'
for column in numerical_columns:
    plt.figure(figsize=(6, 4))
    sns.scatterplot(x=df[column], y=df['quality'])
    plt.title(f'{column} vs Quality')
    plt.show()

# %%
corr = df.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# ## Feature Analysis

# %%
plt.figure(figsize=(13,10))
plt.style.use('dark_background')

# Create a boxplot
sns.boxplot(data=df, x='fixed acidity')
plt.xlabel('Fixed Acidity')
plt.title('Distribution of Fixed Acidity')
plt.xticks(rotation=90)

# Overlay a KDE plot
sns.kdeplot(df['fixed acidity'], color='orange', linewidth=2)
plt.ylabel('Density')

plt.show()

# %%
plt.figure(figsize=(13,10))
plt.style.use('dark_background')

sns.histplot(data=df, x='volatile acidity', kde=True)
plt.xlabel('volatile acidity')
plt.ylabel('Count')
plt.title('Distribution of volatile acidity')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(13,10))
plt.style.use('dark_background')

sns.histplot(data=df, x='citric acid', kde=True)
plt.xlabel('Citric Acid')
plt.ylabel('Count')
plt.title('Distribution of Citric Acid')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(13,10))
plt.style.use('dark_background')

sns.histplot(data=df, x='residual sugar', kde=True)
plt.xlabel('residual sugar')
plt.ylabel('Count')
plt.title('Distribution of residual sugar')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(13,10))
plt.style.use('dark_background')

sns.histplot(data=df, x='chlorides', kde=True)
plt.xlabel('chlorides')
plt.ylabel('Count')
plt.title('Distribution of chlorides')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(13,10))
plt.style.use('dark_background')

sns.histplot(data=df, x='free sulfur dioxide', kde=True)
plt.xlabel('free sulfur dioxide')
plt.ylabel('Count')
plt.title('Distribution of free sulfur dioxide')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(13,10))
plt.style.use('dark_background')

sns.histplot(data=df, x='total sulfur dioxide', kde=True)
plt.xlabel('total sulfur dioxide')
plt.ylabel('Count')
plt.title('Distribution of total sulfur dioxide')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(13,10))
plt.style.use('dark_background')

sns.histplot(data=df, x='density', kde=True)
plt.xlabel('density')
plt.ylabel('Count')
plt.title('Distribution of density')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(13,10))
plt.style.use('dark_background')

sns.histplot(data=df, x='pH', kde=True)
plt.xlabel('pH')
plt.ylabel('Count')
plt.title('Distribution of pH')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(13,10))
plt.style.use('dark_background')

sns.histplot(data=df, x='sulphates', kde=True)
plt.xlabel('sulphates')
plt.ylabel('Count')
plt.title('Distribution of sulphates')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(13,10))
plt.style.use('dark_background')

sns.histplot(data=df, x='alcohol', kde=True)
plt.xlabel('alcohol')
plt.ylabel('Count')
plt.title('Distribution of alcohol')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(13,10))
plt.style.use('dark_background')

sns.histplot(data=df, x='quality', kde=True)
plt.xlabel('quality')
plt.ylabel('Count')
plt.title('Distribution of quality')
plt.xticks(rotation=90)
plt.show()

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# Calculate basic statistics: mean, median, mode, standard deviation, minimum, maximum for the "quality" column.
# Check for outliers or extreme values that might skew the distributi

# %%
plt.figure(figsize=(13,10))
plt.style.use('dark_background')

sns.scatterplot(data=df, x='citric acid', y='volatile acidity')
plt.title('Relationship between Citric Acid and Volatile Acidity')
plt.xlabel('Citric Acid')
plt.ylabel('Volatile Acidity')
plt.show()

# %%
sns.pairplot(df[['citric acid', 'volatile acidity']])

# %%
plt.figure(figsize=(13,10))
plt.style.use('dark_background')
sns.scatterplot(data=df, x='citric acid', y='volatile acidity', hue='pH')
plt.title('Percentage of estimated unemployment rate rate per month')
plt.ylabel('Estimated Unemployment rate')
plt.xticks(rotation= 90)
plt.show()

# %%
selected_columns = ['citric acid', 'volatile acidity', 'pH']
sns.pairplot(df[selected_columns])
plt.suptitle('Pairplot of Citric Acid, Volatile Acidity, and pH', y=1.02)
plt.show()

# %% [markdown]
# Insights and Trends: Quality Distribution:
#
# Normal Distribution: If the histogram forms a bell-shaped curve, it suggests a normal distribution of quality scores. Skewed Distribution: Skewed distributions (positively or negatively skewed) indicate asymmetry in the quality scores. Specific Patterns: Multiple peaks might indicate distinct quality categories or preferences. Correlation with Input Variables:
#
# Strong Positive Correlation: Higher correlation coefficients with factors like alcohol might suggest a significant positive influence on quality. Strong Negative Correlation: Factors negatively correlated with quality might indicate detrimental impacts on wine quality.
