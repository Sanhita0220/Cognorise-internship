# %% [markdown]
# # Cerels Analysis

# %% [markdown]
# Name: Name of cereal
#
# mfr: Manufacturer of cereal
#
# A = American Home Food Products;
#
# G = General Mills
#
# K = Kelloggs
#
# N = Nabisco
#
# P = Post
#
# Q = Quaker Oats
#
# R = Ralston Purina
#
# type:
#
# cold
# hot
#
# calories: calories per serving
#
# protein: grams of protein
#
# fat: grams of fat
#
# sodium: milligrams of sodium
#
# fiber: grams of dietary fiber
#
# carbo: grams of complex carbohydrates
#
# sugars: grams of sugars
#
# potass: milligrams of potassium
#
# vitamins: vitamins and minerals - 0, 25, or 100, indicating the typical percentage of FDA
# recommended
#
# shelf: display shelf (1, 2, or 3, counting from the floor)
#
# weight: weight in ounces of one serving
#
# cups: number of cups in one serving
#
# rating: a rating of the cereals (Possibly from Consumer Reports?)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('cereal.csv')
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df.shape
# Out:
# (77, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
df.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
df.name.unique()
# Out:
# array(['100% Bran', '100% Natural Bran', 'All-Bran',
#        'All-Bran with Extra Fiber', 'Almond Delight',
#        'Apple Cinnamon Cheerios', 'Apple Jacks', 'Basic 4', 'Bran Chex',
#        'Bran Flakes', "Cap'n'Crunch", 'Cheerios', 'Cinnamon Toast Crunch',
#        'Clusters', 'Cocoa Puffs', 'Corn Chex', 'Corn Flakes', 'Corn Pops',
#        'Count Chocula', "Cracklin' Oat Bran", 'Cream of Wheat (Quick)',
#        'Crispix', 'Crispy Wheat & Raisins', 'Double Chex', 'Froot Loops',
#        'Frosted Flakes', 'Frosted Mini-Wheats',
#        'Fruit & Fibre Dates; Walnuts; and Oats', 'Fruitful Bran',
#        'Fruity Pebbles', 'Golden Crisp', 'Golden Grahams',
#        'Grape Nuts Flakes', 'Grape-Nuts', 'Great Grains Pecan',
#        'Honey Graham Ohs', 'Honey Nut Cheerios', 'Honey-comb',
#        'Just Right Crunchy  Nuggets', 'Just Right Fruit & Nut', 'Kix',
#        'Life', 'Lucky Charms', 'Maypo',
#        'Muesli Raisins; Dates; & Almonds',
# ...

# %%
df.name.nunique()
# Out:
# 77

# %%
rating = df['rating']
calories = df['calories']
protein = df['protein']
fat = df['fat']
sodium = df['sodium']
fiber = df['fiber']
carbo = df['carbo']
sugars = df['sugars']
potass = df['potass']
vitamins = df['vitamins']
ingredients = protein + fat + (sodium/100) + fiber + carbo + sugars + (potass/100)

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df['mfr'] = df['mfr'].replace({ 'A':'American Home Food Products','G':'General Mills','K':'Kelloggs','N':'Nabisco','P':'Post','Q':'Quaker Oats','R':'Ralston Purina'})

df['type'] = df['type'].replace({'C':'Cold','H':'Hot'})


df.head()
# Out:
#                         name             mfr  type  calories  protein  fat  \
# 0                  100% Bran         Nabisco  Cold        70        4    1
# 1          100% Natural Bran     Quaker Oats  Cold       120        3    5
# 2                   All-Bran        Kelloggs  Cold        70        4    1
# 3  All-Bran with Extra Fiber        Kelloggs  Cold        50        4    0
# 4             Almond Delight  Ralston Purina  Cold       110        2    2
#
#    sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 0     130   10.0    5.0       6     280        25      3     1.0  0.33
# 1      15    2.0    8.0       8     135         0      3     1.0  1.00
# 2     260    9.0    7.0       5     320        25      3     1.0  0.33
# 3     140   14.0    8.0       0     330        25      3     1.0  0.50
# 4     200    1.0   14.0       8      -1        25      3     1.0  0.75
#
#       rating
# 0  68.402973
# 1  33.983679
# 2  59.425505
# 3  93.704912
# 4  34.384843

# %%
def categorical_data(data):
    for col in data:
        print('*'*20, col, '*'*20,'\n')
        print(data[col].agg(['count', 'unique', 'nunique']))
        print(data[col].value_counts())
        print()

# Numerical data
def numerical_data(data):
    for col in data:
        print('*'*20, col, '*'*20, '\n')
        print(data[col].agg(['count', 'min','max', 'mean', 'median', 'std', 'skew', 'kurt']))
        print()

# %%
categorical_columns = ['mfr','type']

numerical_columns = ['calories', 'protein', 'fat', 'sodium', 'fiber',
       'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
       'rating']
ingredients_columns = ['protein', 'fat', 'sodium', 'fiber',
       'carbo', 'sugars', 'potass']

# %%
categorical_data(df[categorical_columns])
# Out:
# ******************** mfr ********************
#
# count                                                     77
# unique     [Nabisco, Quaker Oats, Kelloggs, Ralston Purin...
# nunique                                                    7
# Name: mfr, dtype: object
# Kelloggs                       23
# General Mills                  22
# Post                            9
# Quaker Oats                     8
# Ralston Purina                  8
# Nabisco                         6
# American Home Food Products     1
# Name: mfr, dtype: int64
#
# ******************** type ********************
#
# count               77
# unique     [Cold, Hot]
# nunique              2
# Name: type, dtype: object
# Cold    74
# Hot      3
# Name: type, dtype: int64

# %%
numerical_data(df[numerical_columns])
# Out:
# ******************** calories ********************
#
# count      77.000000
# min        50.000000
# max       160.000000
# mean      106.883117
# median    110.000000
# std        19.484119
# skew       -0.445407
# kurt        2.370146
# Name: calories, dtype: float64
#
# ******************** protein ********************
#
# count     77.000000
# min        1.000000
# max        6.000000
# mean       2.545455
# median     3.000000
# std        1.094790
# skew       0.745830
# kurt       1.184656
# Name: protein, dtype: float64
#
# ******************** fat ********************
#
# count     77.000000
# min        0.000000
# max        5.000000
# mean       1.012987
# median     1.000000
# std        1.006473
# skew       1.165989
# kurt       2.044655
# Name: fat, dtype: float64
#
# ******************** sodium ********************
#
# count      77.000000
# min         0.000000
# max       320.000000
# mean      159.675325
# median    180.000000
# std        83.832295
# ...

# %%
corr = df.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=True, cmap="Purples")
plt.show()

# %%
categorical_columns = ['mfr','type']

numerical_columns = ['calories', 'protein', 'fat', 'sodium', 'fiber',
       'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
       'rating']

# %%
sns.set_theme(style="ticks")
plt.figure(figsize=(10,10))
sns.boxplot(data=df, x="protein", y="rating", hue="type",color="blue")
plt.xticks(rotation=90)
plt.show()

# %%
sns.set_theme(style="ticks")
plt.figure(figsize=(10,10))
sns.boxplot(data=df, x="fat", y="rating", hue="type",color="green")
plt.xticks(rotation=90)
plt.show()

# %%
sns.set_theme(style="ticks")
plt.figure(figsize=(10,10))
sns.boxplot(data=df, x="sodium", y="rating", hue="type",color="red")
plt.xticks(rotation=90)
plt.show()

# %%
sns.set_theme(style="ticks")
plt.figure(figsize=(10,10))
sns.boxplot(data=df, x="fiber", y="rating", hue="type",color="purple")
plt.xticks(rotation=90)
plt.show()

# %%
sns.set_theme(style="ticks")
plt.figure(figsize=(10,10))
sns.boxplot(data=df, x="carbo", y="rating",hue='type',color='yellow')
plt.xticks(rotation=90)
plt.show()

# %%
sns.set_theme(style="ticks")
plt.figure(figsize=(10,10))
sns.boxplot(data=df, x="sugars", y="rating",hue='type',color='orange')
plt.xticks(rotation=45)
plt.show()

# %%
sns.set_theme(style="ticks")
plt.figure(figsize=(10,10))
sns.boxplot(data=df, x="potass", y="rating", hue="type",color='magenta')
plt.xticks(rotation=90)
plt.show()

# %%
sns.set_theme(style="ticks")
plt.figure(figsize=(10,10))
sns.boxplot(data=df, x="vitamins", y="rating", hue="type",color='pink')
plt.xticks(rotation=90)
plt.show()

# %%
sns.set_theme(style="ticks")
plt.figure(figsize=(10,10))
sns.boxplot(data=df, x="vitamins", y="rating", hue="type",color='teal')
#sns.lineplot(data=df, x="vitamins", y="rating", color="purple")
plt.xticks(rotation=90)
plt.show()

# %%
df.head()
# Out:
#                         name             mfr  type  calories  protein  fat  \
# 0                  100% Bran         Nabisco  Cold        70        4    1
# 1          100% Natural Bran     Quaker Oats  Cold       120        3    5
# 2                   All-Bran        Kelloggs  Cold        70        4    1
# 3  All-Bran with Extra Fiber        Kelloggs  Cold        50        4    0
# 4             Almond Delight  Ralston Purina  Cold       110        2    2
#
#    sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 0     130   10.0    5.0       6     280        25      3     1.0  0.33
# 1      15    2.0    8.0       8     135         0      3     1.0  1.00
# 2     260    9.0    7.0       5     320        25      3     1.0  0.33
# 3     140   14.0    8.0       0     330        25      3     1.0  0.50
# 4     200    1.0   14.0       8      -1        25      3     1.0  0.75
#
#       rating
# 0  68.402973
# 1  33.983679
# 2  59.425505
# 3  93.704912
# 4  34.384843

# %%
manu_max = df.groupby('mfr')['rating','name','cups','type'].max()
manu_max
# Out:
#                                 rating                     name  cups  type
# mfr
# American Home Food Products  54.850917                    Maypo  1.00   Hot
# General Mills                51.592193      Wheaties Honey Gold  1.50  Cold
# Kelloggs                     93.704912                Special K  1.00  Cold
# Nabisco                      74.472949  Strawberry Fruit Wheats  1.00   Hot
# Post                         53.371007    Post Nat. Raisin Bran  1.33  Cold
# Quaker Oats                  63.005645           Quaker Oatmeal  1.00   Hot
# Ralston Purina               49.787445               Wheat Chex  1.13  Cold

# %%
manu_max.plot(kind='barh')
# Out:
# <Axes: ylabel='mfr'>

# %%
manu_min = df.groupby('mfr')['rating','name','cups','type'].min()
manu_min
# Out:
#                                 rating                     name  cups  type
# mfr
# American Home Food Products  54.850917                    Maypo  1.00   Hot
# General Mills                19.823573  Apple Cinnamon Cheerios  0.50  Cold
# Kelloggs                     29.924285                 All-Bran  0.33  Cold
# Nabisco                      59.363993                100% Bran  0.33  Cold
# Post                         28.025765              Bran Flakes  0.25  Cold
# Quaker Oats                  18.042851        100% Natural Bran  0.50  Cold
# Ralston Purina               34.139765           Almond Delight  0.67  Cold

# %%
manu_min.plot(kind='barh',color = 'purple', title='minimum of rating for each manufacturer')
# Out:
# <Axes: title={'center': 'minimum of rating for each manufacturer'}, ylabel='mfr'>

# %%
manu_max.plot(kind='barh',color = 'purple', title='maximum of rating and cups for each manufacturer')
# Out:
# <Axes: title={'center': 'maximum of rating and cups for each manufacturer'}, ylabel='mfr'>
